# %%
import math
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy.interpolate import interp1d
import seaborn as sns
from scipy.stats import linregress
from scipy.optimize import curve_fit

import PythonGraphMod

# %%
pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in /home/pavel/.local/lib/python3.8/site-packages (3.0.10)
# Requirement already satisfied: et-xmlfile in /home/pavel/.local/lib/python3.8/site-packages (from openpyxl) (1.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
fd6 = pd.read_excel("../data/Noise.xlsx")

Channel = np.array(fd6['Channel'])       
Counts = np.array(fd6['Counts'])   

fig6, ax6 = PythonGraphMod.CreateSimpleGraph()

# ax6.scatter(Channel, Counts, color='black', marker='o', s=5, alpha=1)
ax6.plot(Channel, Counts)

# сетка
ax6.minorticks_on()
ax6.grid(which = 'major', color = 'black', linewidth = 1, linestyle = '-', alpha = 0.75)
ax6.grid(which = 'minor', color = 'grey', linewidth = 1, linestyle = '--', alpha = 0.5)

# оформление
plt.title('Спектр фонового шума')
plt.ylabel('Count')
plt.xlabel('Channel')
# ax1.text(5, 350, r'$\Delta V \approx 17.6 \pm 0.02$ В', 
#     size = 8,
#     bbox=dict(facecolor='white', edgecolor='black', pad=10.0))
fig6.savefig('../images/Noise.jpg')

# %%
fd1 = pd.read_excel("../data/Am.xlsx")

Channel = np.array(fd1['Channel'])       
Counts = np.array(fd1['Counts']) - np.array(fd6['Counts'])

fig1, ax1 = PythonGraphMod.CreateSimpleGraph()

# ax1.scatter(Channel, Counts, color='black', marker='o', s=5, alpha=1)
# для большей наглядности выделим часть спектра, где есть интересующая нас информация
# ax1.scatter(Channel[:250], Counts[:250], color='black', marker='o', s=5, alpha=1)
ax1.plot(Channel[:250], Counts[:250])

# сетка
ax1.minorticks_on()
ax1.grid(which = 'major', color = 'black', linewidth = 1, linestyle = '-', alpha = 0.75)
ax1.grid(which = 'minor', color = 'grey', linewidth = 1, linestyle = '--', alpha = 0.5)

# оформление
plt.title('Спектр для Am')
plt.ylabel('Count')
plt.xlabel('Channel')
# ax1.text(5, 350, r'$\Delta V \approx 17.6 \pm 0.02$ В', 
#     size = 8,
#     bbox=dict(facecolor='white', edgecolor='black', pad=10.0))
fig1.savefig('../images/Am.jpg')

# %%
fd2 = pd.read_excel("../data/Co.xlsx")

Channel = np.array(fd2['Channel'])         
Counts = np.array(fd2['Counts']) - np.array(fd6['Counts'])     

fig2, ax2 = PythonGraphMod.CreateSimpleGraph()

# ax2.scatter(Channel, Counts, color='black', marker='o', s=5, alpha=1)
ax2.plot(Channel, Counts)

# сетка
ax2.minorticks_on()
ax2.grid(which = 'major', color = 'black', linewidth = 1, linestyle = '-', alpha = 0.75)
ax2.grid(which = 'minor', color = 'grey', linewidth = 1, linestyle = '--', alpha = 0.5)

# оформление
plt.title('Спектр для Co')
plt.ylabel('Count')
plt.xlabel('Channel')
# ax1.text(5, 350, r'$\Delta V \approx 17.6 \pm 0.02$ В', 
#     size = 8,
#     bbox=dict(facecolor='white', edgecolor='black', pad=10.0))
fig2.savefig('../images/Co.jpg')

# %%
fd3 = pd.read_excel("../data/Cs.xlsx")

Channel = np.array(fd3['Channel'])       
Counts = np.array(fd3['Counts']) - np.array(fd6['Counts'])   

fig3, ax3 = PythonGraphMod.CreateSimpleGraph()

# ax3.scatter(Channel, Counts, color='black', marker='o', s=5, alpha=1)
# для большей наглядности выделим часть спектра, где есть интересующая нас информация
# ax3.scatter(Channel[:1250], Counts[:1250], color='black', marker='o', s=5, alpha=1)
ax3.plot(Channel, Counts)

# сетка
ax3.minorticks_on()
ax3.grid(which = 'major', color = 'black', linewidth = 1, linestyle = '-', alpha = 0.75)
ax3.grid(which = 'minor', color = 'grey', linewidth = 1, linestyle = '--', alpha = 0.5)

# оформление
plt.title('Спектр для Cs')
plt.ylabel('Count')
plt.xlabel('Channel')
# ax1.text(5, 350, r'$\Delta V \approx 17.6 \pm 0.02$ В', 
#     size = 8,
#     bbox=dict(facecolor='white', edgecolor='black', pad=10.0))
fig3.savefig('../images/Cs.jpg')

# %%
fd4 = pd.read_excel("../data/Eu.xlsx")

Channel = np.array(fd4['Channel'])       
Counts = np.array(fd4['Counts']) - np.array(fd6['Counts'])   

fig4, ax4 = PythonGraphMod.CreateSimpleGraph()

# ax4.scatter(Channel, Counts, color='black', marker='o', s=5, alpha=1)
ax4.plot(Channel, Counts)

# сетка
ax4.minorticks_on()
ax4.grid(which = 'major', color = 'black', linewidth = 1, linestyle = '-', alpha = 0.75)
ax4.grid(which = 'minor', color = 'grey', linewidth = 1, linestyle = '--', alpha = 0.5)

# оформление
plt.title('Спектр для Eu')
plt.ylabel('Count')
plt.xlabel('Channel')
# ax1.text(5, 350, r'$\Delta V \approx 17.6 \pm 0.02$ В', 
#     size = 8,
#     bbox=dict(facecolor='white', edgecolor='black', pad=10.0))


# fig, ax41, ax42 = PythonGraphMod.CreateDoubleGraph()

# ax41.scatter(Channel[:800], Counts[:800], color='black', marker='o', s=5, alpha=1)
# ax42.scatter(Channel[800:], Counts[800:], color='black', marker='o', s=5, alpha=1)
# ax41.grid()
# ax42.grid()
fig4.savefig('../images/Eu.jpg')

# %%
fd5 = pd.read_excel("../data/X.xlsx")

Channel = np.array(fd5['Channel'])       
Counts = np.array(fd5['Counts']) - np.array(fd6['Counts'])  

fig5, ax5 = PythonGraphMod.CreateSimpleGraph()

# ax5.scatter(Channel, Counts, color='black', marker='o', s=5, alpha=1)
ax5.plot(Channel, Counts)

# сетка
ax5.minorticks_on()
ax5.grid(which = 'major', color = 'black', linewidth = 1, linestyle = '-', alpha = 0.75)
ax5.grid(which = 'minor', color = 'grey', linewidth = 1, linestyle = '--', alpha = 0.5)

# оформление
plt.title('Спектр для неизвестного элемента')
plt.ylabel('Count')
plt.xlabel('Channel')
# ax1.text(5, 350, r'$\Delta V \approx 17.6 \pm 0.02$ В', 
#     size = 8,
#     bbox=dict(facecolor='white', edgecolor='black', pad=10.0))
fig5.savefig('../images/Na.jpg')

# %%
fig = plt.figure(figsize=(18, 10))

plt.subplot(3, 2, 1)
plt.plot(np.array(fd6['Channel']), np.array(fd6['Counts']))
plt.xlabel('Channel')
plt.ylabel('Counts')
plt.title('Noise')
plt.grid()

plt.subplot(3, 2, 2)
plt.plot(np.array(fd1['Channel']), np.array(fd1['Counts']))
plt.xlabel('Channel')
plt.ylabel('Counts')
plt.title('Am')
plt.grid()

plt.subplot(3, 2, 3)
plt.plot(np.array(fd2['Channel']), np.array(fd2['Counts']))
plt.xlabel('Channel')
plt.ylabel('Counts')
plt.title('Co')
plt.grid()

plt.subplot(3, 2, 4)
plt.plot(np.array(fd3['Channel']), np.array(fd3['Counts']))
plt.xlabel('Channel')
plt.ylabel('Counts')
plt.title('Cs')
plt.grid()

plt.subplot(3, 2, 5)
plt.plot(np.array(fd4['Channel']), np.array(fd4['Counts']))
plt.xlabel('Channel')
plt.ylabel('Counts')
plt.title('Eu')
plt.grid()

plt.subplot(3, 2, 6)
plt.plot(np.array(fd5['Channel']), np.array(fd5['Counts']))
plt.xlabel('Channel')
plt.ylabel('Counts')
plt.title('Na')
plt.grid()

fig.savefig('../images/all_graphs.pdf')

# %%
fig = plt.figure()

x = np.array([725, 920, 1710])
y = np.array([511, 662, 1275])

lin = linregress(x, y)

plt.scatter(x, y)
plt.plot(x, lin.intercept + lin.slope * x)
plt.xlabel('Channel')
plt.ylabel('Energy')
plt.grid()

fig.savefig('../images/Channel2Energy.pdf')

# %%
fd7 = pd.read_excel("../data/main.ods")

fig = plt.figure()

Ei = np.array(fd7['Ei, eV'])
Ri = np.array(fd7['Ri'])

# исключаем значение для Am
Ei = np.delete(Ei, 5)
Ri = np.delete(Ri, 5)

# удалим выбивающуюся точку
Ei = np.delete(Ei, 6)
Ri = np.delete(Ri, 6)

lin = linregress(1/Ei, np.square(Ri))

plt.scatter(1/Ei, np.square(Ri))
plt.plot(1/Ei, 1/Ei*lin.slope + lin.intercept)
plt.xlabel('1/E')
plt.ylabel(r'$R^2$')
plt.grid()

plt.savefig('../images/R2.pdf')
