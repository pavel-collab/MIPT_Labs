# %%
import math
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy.interpolate import interp1d
import seaborn as sns
from scipy.stats import linregress
from scipy.optimize import curve_fit
import sympy
from heapq import nlargest

import PythonGraphMod

# import math

# %%
fd1 = pd.read_excel("../data/loc_V_4.ods")

U1 = np.array(fd1['V'])        # напряжение В
I1 = np.array(fd1['I']) * 1000 # ток мкА

fig1, ax1 = PythonGraphMod.CreateSimpleGraph()

U_dence1, I_dence1 = PythonGraphMod.InterpolateSet(U1, I1, 'cubic', U1[0], U1[-1])

ax1.scatter(U1, I1, color='black', marker='o', s=8, alpha=1)
ax1.plot(U_dence1, I_dence1, color='blue', alpha=0.75, lw=1.5, ls='-')

## Пики графика
# I[8] = 274 мкА
# I[26] = 419 мкА
# dU = 17.59 = 17.6 В

# рисуем вертикальную линию, отмечаем точку пересечения
ax1.vlines( U1[8], I1.min(), I1[8], ls='-.', color='red', alpha=0.75)
ax1.vlines( U1[26], I1.min(), I1[26], ls='-.', color='red', alpha=0.75)
ax1.scatter(U1[8], I1[8], color='black', marker='o', s=15, alpha=1)
ax1.scatter(U1[26], I1[26], color='black', marker='o', s=15, alpha=1)

# сетка
ax1.minorticks_on()
ax1.grid(which = 'major', color = 'black', linewidth = 1, linestyle = '-', alpha = 0.75)
ax1.grid(which = 'minor', color = 'grey', linewidth = 1, linestyle = '--', alpha = 0.5)

# оформление
plt.title('Вольтамперная характиристика')
plt.ylabel('I, мкА')
plt.xlabel('U, В')
ax1.text(5, 350, r'$\Delta V \approx 17.6 \pm 0.02$ В', 
    size = 8,
    bbox=dict(facecolor='white', edgecolor='black', pad=10.0))

fig1.savefig("../images/loc_V_4.pdf")

# %%
fd2 = pd.read_excel("../data/loc_V_6.ods")

U2 = np.array(fd2['V'])        # напряжение В
I2 = np.array(fd2['I']) * 1000 # ток мкА

fig2, ax2 = PythonGraphMod.CreateSimpleGraph()

U_dence2, I_dence2 = PythonGraphMod.InterpolateSet(U2, I2, 'cubic', U2[0], U2[-1])

ax2.scatter(U2, I2, color='black', marker='o', s=8, alpha=1)
ax2.plot(U_dence2, I_dence2, color='blue', alpha=0.75, lw=1.5, ls='-')
# ax2.plot(U, I, color='red', alpha=0.75, lw=1.5, ls='-')

## Пики графика
# I[9] = 263 мкА
# I[26] = 347 мкА
# dU = 19.0 В

# рисуем вертикальную линию, отмечаем точку пересечения
ax2.vlines(U2[9], I2.min(), I2[9], ls='-.', color='red', alpha=0.75)
ax2.vlines(U2[26], I2.min(), I2[26], ls='-.', color='red', alpha=0.75)
ax2.scatter(U2[8], I2[8], color='black', marker='o', s=15, alpha=1)
ax2.scatter(U2[26], I2[26], color='black', marker='o', s=15, alpha=1)


# сетка
ax2.minorticks_on()
ax2.grid(which = 'major', color = 'black', linewidth = 1, linestyle = '-', alpha = 0.75)
ax2.grid(which = 'minor', color = 'grey', linewidth = 1, linestyle = '--', alpha = 0.5)

# оформление
plt.title('Вольтамперная характиристика')
plt.ylabel('I, мкА')
plt.xlabel('U, В')
ax2.text(5, 325, r'$\Delta V \approx 19.0 \pm 0.02$ В', 
    size = 8,
    bbox=dict(facecolor='white', edgecolor='black', pad=10.0))

fig2.savefig("../images/loc_V_6.pdf")

# %%
fd3 = pd.read_excel("../data/loc_V_9.ods")

U3 = np.array(fd3['V'])        # напряжение В
I3 = np.array(fd3['I']) * 1000 # ток мкА

fig3, ax3 = PythonGraphMod.CreateSimpleGraph()

U_dence3, I_dence3 = PythonGraphMod.InterpolateSet(U3, I3, 'cubic', U3[0], U3[-1])

ax3.scatter(U3, I3, color='black', marker='o', s=8, alpha=1)
# ax3.plot(U_dence, I_dence, color='blue', alpha=0.75, lw=1.5, ls='-')
ax3.plot(U3, I3, color='red', alpha=0.75, lw=1.5, ls='-')

# print(U[27] - U[7])

## Пики графика
# I[7] = 236 мкА
# I[22] = 255 мкА
# dU = 17.0 В

# рисуем вертикальную линию, отмечаем точку пересечения
ax3.vlines(U3[7], I3.min(), I3[7], ls='-.', color='blue', alpha=0.75)
ax3.vlines(U3[22], I3.min(), I3[22], ls='-.', color='blue', alpha=0.75)
ax3.scatter(U3[7], I3[7], color='black', marker='o', s=15, alpha=1)
ax3.scatter(U3[22], I3[22], color='black', marker='o', s=15, alpha=1)

# сетка
ax3.minorticks_on()
ax3.grid(which = 'major', color = 'black', linewidth = 1, linestyle = '-', alpha = 0.75)
ax3.grid(which = 'minor', color = 'grey', linewidth = 1, linestyle = '--', alpha = 0.5)

# оформление
plt.title('Вольтамперная характиристика')
plt.ylabel('I, мкА')
plt.xlabel('U, В')
ax3.text(5, 225, r'$\Delta V \approx 17.0 \pm 0.02$ В', 
    size = 8,
    bbox=dict(facecolor='white', edgecolor='black', pad=10.0))

fig3.savefig("../images/loc_V_9.pdf")

# %%
fig4, ax4 = PythonGraphMod.CreateSimpleGraph()

ax4.scatter(U1, I1, color='black', marker='o', s=8, alpha=1)
ax4.plot(U_dence1, I_dence1, color='blue', alpha=0.75, lw=1.5, ls='-', label='loc V = 4 V')

ax4.scatter(U2, I2, color='black', marker='o', s=8, alpha=1)
ax4.plot(U_dence2, I_dence2, color='green', alpha=0.75, lw=1.5, ls='-', label='loc V = 6 V')

ax4.scatter(U3, I3, color='black', marker='o', s=8, alpha=1)
ax4.plot(U3, I3, color='red', alpha=0.75, lw=1.5, ls='-', label='loc V = 9 V')

# сетка
ax4.minorticks_on()
ax4.grid(which = 'major', color = 'black', linewidth = 1, linestyle = '-', alpha = 0.75)
ax4.grid(which = 'minor', color = 'grey', linewidth = 1, linestyle = '--', alpha = 0.5)

# оформление
plt.title('Вольтамперные характиристики')
plt.ylabel('I, мкА')
plt.xlabel('U, В')
plt.legend()

fig4.savefig("../images/VAC.pdf")
